# %%
import torch
import numpy as np
import pandas as pd

from pymatgen.core import Structure
from pymatgen.io.cif import CifWriter

def generate_cif(row):
    """Generate cif file from row of dataframe."""
    crystal_str = row['cif']
    structure = Structure.from_str(crystal_str, fmt='cif')
    structure *= [2,2,2]
    cif_writer = CifWriter(structure)
    cif_content = str(cif_writer)
    return cif_content

# %%
# test_zpc.
df = pd.read_csv('./test_zpc.csv')
df['cif'] = df.apply(generate_cif, axis=1)

output_csv_file = './cs2_test_zpc.csv'
df.to_csv(output_csv_file, index=False)

print(f"CSV with updated CIF saved to {output_csv_file}")
# Out:
# CSV with updated CIF saved to ./data/cs2_test_zpc.csv

# %%
# train.
df = pd.read_csv('./train.csv')
df['cif'] = df.apply(generate_cif, axis=1)

output_csv_file = './cs2_train.csv'
df.to_csv(output_csv_file, index=False)

print(f"CSV with updated CIF saved to {output_csv_file}")
# Out:
# /home/xzdai/anaconda3/envs/chggen/lib/python3.8/site-packages/pymatgen/io/cif.py:1168: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# CSV with updated CIF saved to ./data/cs2_train.csv

# %%
# val.
df = pd.read_csv('./val.csv')
df['cif'] = df.apply(generate_cif, axis=1)

output_csv_file = './cs2_val.csv'
df.to_csv(output_csv_file, index=False)

print(f"CSV with updated CIF saved to {output_csv_file}")
# Out:
# /home/xzdai/anaconda3/envs/chggen/lib/python3.8/site-packages/pymatgen/io/cif.py:1168: UserWarning: Issues encountered while parsing CIF: Some fractional coordinates rounded to ideal values to avoid issues with finite precision.
#   warnings.warn("Issues encountered while parsing CIF: " + "\n".join(self.warnings))
# CSV with updated CIF saved to ./data/cs2_val.csv

# %%
# val.
df = pd.read_csv('./cs2_test_zpc.csv')

# %%
Structure.from_str(df.iloc[0]['cif'], 'cif')
# Out:
# Structure Summary
# Lattice
#     abc : 8.1126432 8.1126432 8.1126432
#  angles : 90.0 90.0 90.0
#  volume : 533.9334474443236
#       A : 8.1126432 0.0 4.967561263752271e-16
#       B : -4.967561263752271e-16 8.1126432 4.967561263752271e-16
#       C : 0.0 0.0 8.1126432
#     pbc : True True True
# PeriodicSite: Ti0 (Ti) (2.471, 0.0, 1.513e-16) [0.3046, 0.0, 0.0]
# PeriodicSite: Ti0 (Ti) (2.471, 0.0, 4.056) [0.3046, 0.0, 0.5]
# PeriodicSite: Ti0 (Ti) (2.471, 4.056, 3.997e-16) [0.3046, 0.5, 0.0]
# PeriodicSite: Ti0 (Ti) (2.471, 4.056, 4.056) [0.3046, 0.5, 0.5]
# PeriodicSite: Ti0 (Ti) (6.527, 0.0, 3.997e-16) [0.8046, 0.0, 0.0]
# PeriodicSite: Ti0 (Ti) (6.527, 0.0, 4.056) [0.8046, 0.0, 0.5]
# PeriodicSite: Ti0 (Ti) (6.527, 4.056, 6.481e-16) [0.8046, 0.5, 0.0]
# PeriodicSite: Ti0 (Ti) (6.527, 4.056, 4.056) [0.8046, 0.5, 0.5]
# PeriodicSite: Os1 (Os) (3.149, 2.028, 2.028) [0.3881, 0.25, 0.25]
# PeriodicSite: Os1 (Os) (3.149, 2.028, 6.084) [0.3881, 0.25, 0.75]
# PeriodicSite: Os1 (Os) (3.149, 6.084, 2.028) [0.3881, 0.75, 0.25]
# PeriodicSite: Os1 (Os) (3.149, 6.084, 6.084) [0.3881, 0.75, 0.75]
# PeriodicSite: Os1 (Os) (7.205, 2.028, 2.028) [0.8881, 0.25, 0.25]
# PeriodicSite: Os1 (Os) (7.205, 2.028, 6.084) [0.8881, 0.25, 0.75]
# PeriodicSite: Os1 (Os) (7.205, 6.084, 2.028) [0.8881, 0.75, 0.25]
# PeriodicSite: Os1 (Os) (7.205, 6.084, 6.084) [0.8881, 0.75, 0.75]
# PeriodicSite: N3 (N) (3.01, 2.028, 3.085e-16) [0.371, 0.25, 0.0]
# PeriodicSite: N3 (N) (3.01, 2.028, 4.056) [0.371, 0.25, 0.5]
# PeriodicSite: N3 (N) (3.01, 6.084, 5.569e-16) [0.371, 0.75, 0.0]
# PeriodicSite: N3 (N) (3.01, 6.084, 4.056) [0.371, 0.75, 0.5]
# PeriodicSite: N3 (N) (7.066, 2.028, 5.569e-16) [0.871, 0.25, 0.0]
# PeriodicSite: N3 (N) (7.066, 2.028, 4.056) [0.871, 0.25, 0.5]
# PeriodicSite: N3 (N) (7.066, 6.084, 8.052e-16) [0.871, 0.75, 0.0]
# PeriodicSite: N3 (N) (7.066, 6.084, 4.056) [0.871, 0.75, 0.5]
# PeriodicSite: O4 (O) (0.9388, 2.028, 2.028) [0.1157, 0.25, 0.25]
# PeriodicSite: O4 (O) (0.9388, 2.028, 6.084) [0.1157, 0.25, 0.75]
# PeriodicSite: O4 (O) (0.9388, 6.084, 2.028) [0.1157, 0.75, 0.25]
# PeriodicSite: O4 (O) (0.9388, 6.084, 6.084) [0.1157, 0.75, 0.75]
# PeriodicSite: O4 (O) (4.995, 2.028, 2.028) [0.6157, 0.25, 0.25]
# PeriodicSite: O4 (O) (4.995, 2.028, 6.084) [0.6157, 0.25, 0.75]
# PeriodicSite: O4 (O) (4.995, 6.084, 2.028) [0.6157, 0.75, 0.25]
# PeriodicSite: O4 (O) (4.995, 6.084, 6.084) [0.6157, 0.75, 0.75]
# PeriodicSite: F2 (F) (1.685, 0.0, 2.028) [0.2076, 0.0, 0.25]
# PeriodicSite: F2 (F) (1.685, 0.0, 6.084) [0.2076, 0.0, 0.75]
# PeriodicSite: F2 (F) (1.685, 4.056, 2.028) [0.2076, 0.5, 0.25]
# PeriodicSite: F2 (F) (1.685, 4.056, 6.084) [0.2076, 0.5, 0.75]
# PeriodicSite: F2 (F) (5.741, 0.0, 2.028) [0.7076, 0.0, 0.25]
# PeriodicSite: F2 (F) (5.741, 0.0, 6.084) [0.7076, 0.0, 0.75]
# PeriodicSite: F2 (F) (5.741, 4.056, 2.028) [0.7076, 0.5, 0.25]
# PeriodicSite: F2 (F) (5.741, 4.056, 6.084) [0.7076, 0.5, 0.75]
